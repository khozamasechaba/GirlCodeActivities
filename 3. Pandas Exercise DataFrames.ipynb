# %%
import numpy as np
import pandas as pd

import os
current_directory = os.getcwd()
print(current_directory)
# Out:
# /mnt/c/WINDOWS/system32

# %%
df = pd.DataFrame({
    'Population':[35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'GDP':[
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067
    ],
       'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]

}, columns = ['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'])

# %%
df
#Dataframe Column is a series
# Out:
#    Population       GDP  Surface Area    HDI Continent
# 0      35.467   1785387       9984670  0.913   America
# 1      63.951   2833687        640679  0.888    Europe
# 2      80.940   3874437        357114  0.916    Europe
# 3      60.665   2167744        301336  0.873    Europe
# 4     127.061   4602367        377930  0.891      Asia
# 5      64.511   2950039        242495  0.907    Europe
# 6     318.523  17348075       9525067  0.915   America

# %%
df.index = [
    'Canada','France','Germany','Italy','Japan','UK','USA'

]

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %%
df.index
# Out:
# Index(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'UK', 'USA'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to USA
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    7 non-null      float64
#  1   GDP           7 non-null      int64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 336.0+ bytes

# %%
df.size
# Out:
# 35

# %%
df.shape
# Out:
# (7, 5)

# %%
df.describe()
# Out:
#        Population           GDP  Surface Area       HDI
# count    7.000000  7.000000e+00  7.000000e+00  7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429
# std     97.249970  5.494020e+06  4.576187e+06  0.016592
# min     35.467000  1.785387e+06  2.424950e+05  0.873000
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000
# max    318.523000  1.734808e+07  9.984670e+06  0.916000

# %%
df.dtypes
# Out:
# Population      float64
# GDP               int64
# Surface Area      int64
# HDI             float64
# Continent        object
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# float64    2
# int64      2
# object     1
# dtype: int64

# %%
#Index, Slice, Select
df
#Select by index using loc, so loc selects rows by index
#iloc will let select row, by sequential pos
#Results are all series, where index of dataframe becomes the name
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# UK           64.511   2950039        242495  0.907    Europe
# USA         318.523  17348075       9525067  0.915   America

# %%
df['Population']
# Out:
# Canada      35.467
# France      63.951
# Germany     80.940
# Italy       60.665
# Japan      127.061
# UK          64.511
# USA        318.523
# Name: Population, dtype: float64

# %%
df.loc['Canada']
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.iloc[-1]
# Out:
# Population       318.523
# GDP             17348075
# Surface Area     9525067
# HDI                0.915
# Continent        America
# Name: USA, dtype: object

# %%
#can make result a frame
df['Population'].to_frame()
# Out:
#          Population
# Canada       35.467
# France       63.951
# Germany      80.940
# Italy        60.665
# Japan       127.061
# UK           64.511
# USA         318.523

# %%
df[['Population', 'GDP']] #Select multiple
# Out:
#          Population       GDP
# Canada       35.467   1785387
# France       63.951   2833687
# Germany      80.940   3874437
# Italy        60.665   2167744
# Japan       127.061   4602367
# UK           64.511   2950039
# USA         318.523  17348075

# %%
df[1:3]#Slice
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe

# %%
#loc iloc preferred for slice
df.loc['Italy']
# Out:
# Population       60.665
# GDP             2167744
# Surface Area     301336
# HDI               0.873
# Continent        Europe
# Name: Italy, dtype: object

# %%
df.loc['France':'Italy']#NB, upper bound INCLUDEd
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe
# Italy        60.665  2167744        301336  0.873    Europe

# %%
#slice, and isolate
df.loc['France':'Italy', 'Continent']
# Out:
# France     Europe
# Germany    Europe
# Italy      Europe
# Name: Continent, dtype: object

# %%
df.loc['France':'Italy', ['GDP','HDI']]
# Out:
#              GDP    HDI
# France   2833687  0.888
# Germany  3874437  0.916
# Italy    2167744  0.873

# %%
#iloc works with numeric postition
df
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# UK           64.511   2950039        242495  0.907    Europe
# USA         318.523  17348075       9525067  0.915   America

# %%
df.iloc[0]
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.iloc[-1]
# Out:
# Population       318.523
# GDP             17348075
# Surface Area     9525067
# HDI                0.915
# Continent        America
# Name: USA, dtype: object

# %%
df.iloc[[1,1,-1]]#Select mult
# Out:
#         Population       GDP  Surface Area    HDI Continent
# France      63.951   2833687        640679  0.888    Europe
# France      63.951   2833687        640679  0.888    Europe
# USA        318.523  17348075       9525067  0.915   America

# %%
df.iloc[1:3,3]
# Out:
# France     0.888
# Germany    0.916
# Name: HDI, dtype: float64

# %%
df.iloc[1:3, 1:3]
# Out:
#              GDP  Surface Area
# France   2833687        640679
# Germany  3874437        357114

# %%
df
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# UK           64.511   2950039        242495  0.907    Europe
# USA         318.523  17348075       9525067  0.915   America

# %%
#Conditional Selection
df
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# UK           64.511   2950039        242495  0.907    Europe
# USA         318.523  17348075       9525067  0.915   America

# %%
df['Population'].mean()
# Out:
# 107.30257142857144

# %%
df['Population'] > 70
# Out:
# Canada     False
# France     False
# Germany     True
# Italy      False
# Japan       True
# UK         False
# USA         True
# Name: Population, dtype: bool

# %%
df.loc[df['Population']>70]
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Germany      80.940   3874437        357114  0.916    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# USA         318.523  17348075       9525067  0.915   America

# %%
#Boolean matching at index level, filter by  row, with right indexes
df.loc[df['Population']>70,'Population']
# Out:
# Germany     80.940
# Japan      127.061
# USA        318.523
# Name: Population, dtype: float64

# %%
df.loc[df['Population']>70,['Population','GDP']]
# Out:
#          Population       GDP
# Germany      80.940   3874437
# Japan       127.061   4602367
# USA         318.523  17348075

# %%
#Modifying
df.drop(['Canada'])
#Drop by index
# Out:
#          Population       GDP  Surface Area    HDI Continent
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# UK           64.511   2950039        242495  0.907    Europe
# USA         318.523  17348075       9525067  0.915   America

# %%
#drop
df.drop(['France','Japan'])
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# UK           64.511   2950039        242495  0.907    Europe
# USA         318.523  17348075       9525067  0.915   America

# %%
#Drop colums
df.drop(columns=['Population','HDI'])
# Out:
#               GDP  Surface Area Continent
# Canada    1785387       9984670   America
# France    2833687        640679    Europe
# Germany   3874437        357114    Europe
# Italy     2167744        301336    Europe
# Japan     4602367        377930      Asia
# UK        2950039        242495    Europe
# USA      17348075       9525067   America

# %%
df.drop(['Italy','Canada'],axis=0)
# Out:
#          Population       GDP  Surface Area    HDI Continent
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# UK           64.511   2950039        242495  0.907    Europe
# USA         318.523  17348075       9525067  0.915   America

# %%
df.drop(['Population','HDI'],axis=1)
#Can also say axis=rows (0)
#axis = columns (1)
# Out:
#               GDP  Surface Area Continent
# Canada    1785387       9984670   America
# France    2833687        640679    Europe
# Germany   3874437        357114    Europe
# Italy     2167744        301336    Europe
# Japan     4602367        377930      Asia
# UK        2950039        242495    Europe
# USA      17348075       9525067   America

# %%
#Operations
df[['Population','GDP']]
# Out:
#          Population       GDP
# Canada       35.467   1785387
# France       63.951   2833687
# Germany      80.940   3874437
# Italy        60.665   2167744
# Japan       127.061   4602367
# UK           64.511   2950039
# USA         318.523  17348075

# %%
df[['Population','GDP']]/100
# Out:
#          Population        GDP
# Canada      0.35467   17853.87
# France      0.63951   28336.87
# Germany     0.80940   38744.37
# Italy       0.60665   21677.44
# Japan       1.27061   46023.67
# UK          0.64511   29500.39
# USA         3.18523  173480.75

# %%
#operations w S happen at column level. brroadcaition down the rows, couter intuitive
crisis = pd.Series([-1_000_000, -0.3], index = ['GDP', 'HDI'])
crisis
# Out:
# GDP   -1000000.0
# HDI         -0.3
# dtype: float64

# %%
df[['GDP','HDI']]
# Out:
#               GDP    HDI
# Canada    1785387  0.913
# France    2833687  0.888
# Germany   3874437  0.916
# Italy     2167744  0.873
# Japan     4602367  0.891
# UK        2950039  0.907
# USA      17348075  0.915

# %%
df[['GDP','HDI']] + crisis
# Out:
#                 GDP    HDI
# Canada     785387.0  0.613
# France    1833687.0  0.588
# Germany   2874437.0  0.616
# Italy     1167744.0  0.573
# Japan     3602367.0  0.591
# UK        1950039.0  0.607
# USA      16348075.0  0.615

# %%
#works like: 1_000_000 - GDP
#and 0,3 - HDI

# %%
#When dropping, we were not actually modifying. The actual DF is not changing. Operation are immutable
#So, we
lang = pd.Series(
    [
        'French', 'German', 'Italian'

    ],

    index = ['French', 'German', 'Italy'],
    name = 'Language'

)

# %%
df['Language'] = lang

# %%
df
# Out:
#          Population       GDP  Surface Area    HDI Continent Language
# Canada       35.467   1785387       9984670  0.913   America      NaN
# France       63.951   2833687        640679  0.888    Europe      NaN
# Germany      80.940   3874437        357114  0.916    Europe      NaN
# Italy        60.665   2167744        301336  0.873    Europe  Italian
# Japan       127.061   4602367        377930  0.891      Asia      NaN
# UK           64.511   2950039        242495  0.907    Europe      NaN
# USA         318.523  17348075       9525067  0.915   America      NaN

# %%
#Replace val

# %%
df['Language'] = 'English'
#To see that operation is changing, you have assignment(=)

# %%
df
# Out:
#          Population       GDP  Surface Area    HDI Continent Language
# Canada       35.467   1785387       9984670  0.913   America  English
# France       63.951   2833687        640679  0.888    Europe  English
# Germany      80.940   3874437        357114  0.916    Europe  English
# Italy        60.665   2167744        301336  0.873    Europe  English
# Japan       127.061   4602367        377930  0.891      Asia  English
# UK           64.511   2950039        242495  0.907    Europe  English
# USA         318.523  17348075       9525067  0.915   America  English

# %%
#Rename col
df.rename(
    columns = { 'HDI': 'Human Development Index',
        'Anual Popcorn Consumption': 'APC'},
    index = {  'United States': 'USA',
        'United Kingdom': 'UK',
        'Argentina': 'AR'},
)
# Out:
#          Population       GDP  Surface Area  Human Development Index  \
# Canada       35.467   1785387       9984670                    0.913
# France       63.951   2833687        640679                    0.888
# Germany      80.940   3874437        357114                    0.916
# Italy        60.665   2167744        301336                    0.873
# Japan       127.061   4602367        377930                    0.891
# UK           64.511   2950039        242495                    0.907
# USA         318.523  17348075       9525067                    0.915
#
#         Continent Language
# Canada    America  English
# France     Europe  English
# Germany    Europe  English
# Italy      Europe  English
# Japan        Asia  English
# UK         Europe  English
# USA       America  English

# %%
df
# Out:
#          Population       GDP  Surface Area    HDI Continent Language
# Canada       35.467   1785387       9984670  0.913   America  English
# France       63.951   2833687        640679  0.888    Europe  English
# Germany      80.940   3874437        357114  0.916    Europe  English
# Italy        60.665   2167744        301336  0.873    Europe  English
# Japan       127.061   4602367        377930  0.891      Asia  English
# UK           64.511   2950039        242495  0.907    Europe  English
# USA         318.523  17348075       9525067  0.915   America  English

# %%
#make to uppercase
df.rename(index = str.upper)
# Out:
#          Population       GDP  Surface Area    HDI Continent Language
# CANADA       35.467   1785387       9984670  0.913   America  English
# FRANCE       63.951   2833687        640679  0.888    Europe  English
# GERMANY      80.940   3874437        357114  0.916    Europe  English
# ITALY        60.665   2167744        301336  0.873    Europe  English
# JAPAN       127.061   4602367        377930  0.891      Asia  English
# UK           64.511   2950039        242495  0.907    Europe  English
# USA         318.523  17348075       9525067  0.915   America  English

# %%
df.rename(index = lambda x:x.lower())
# Out:
#          Population       GDP  Surface Area    HDI Continent Language
# canada       35.467   1785387       9984670  0.913   America  English
# france       63.951   2833687        640679  0.888    Europe  English
# germany      80.940   3874437        357114  0.916    Europe  English
# italy        60.665   2167744        301336  0.873    Europe  English
# japan       127.061   4602367        377930  0.891      Asia  English
# uk           64.511   2950039        242495  0.907    Europe  English
# usa         318.523  17348075       9525067  0.915   America  English

# %%
#Creatin columns from other columns
df['GDP Per Capita'] = df['GDP'] / df['Population']

# %%
df
# Out:
#          Population       GDP  Surface Area    HDI Continent Language  \
# Canada       35.467   1785387       9984670  0.913   America  English
# France       63.951   2833687        640679  0.888    Europe  English
# Germany      80.940   3874437        357114  0.916    Europe  English
# Italy        60.665   2167744        301336  0.873    Europe  English
# Japan       127.061   4602367        377930  0.891      Asia  English
# UK           64.511   2950039        242495  0.907    Europe  English
# USA         318.523  17348075       9525067  0.915   America  English
#
#          GDP Per Capita
# Canada     50339.385908
# France     44310.284437
# Germany    47868.013343
# Italy      35733.025633
# Japan      36221.712406
# UK         45729.239975
# USA        54464.120330

# %%
#population for surface area
df['Population Per Surface Area'] = df['Population']/df['Surface Area']

# %%
df
# Out:
#          Population       GDP  Surface Area    HDI Continent Language  \
# Canada       35.467   1785387       9984670  0.913   America  English
# France       63.951   2833687        640679  0.888    Europe  English
# Germany      80.940   3874437        357114  0.916    Europe  English
# Italy        60.665   2167744        301336  0.873    Europe  English
# Japan       127.061   4602367        377930  0.891      Asia  English
# UK           64.511   2950039        242495  0.907    Europe  English
# USA         318.523  17348075       9525067  0.915   America  English
#
#          GDP Per Capita  Population Per Surface Area
# Canada     50339.385908                     0.000004
# France     44310.284437                     0.000100
# Germany    47868.013343                     0.000227
# Italy      35733.025633                     0.000201
# Japan      36221.712406                     0.000336
# UK         45729.239975                     0.000266
# ...

# %%
df.describe()
# Out:
#        Population           GDP  Surface Area       HDI  GDP Per Capita  \
# count    7.000000  7.000000e+00  7.000000e+00  7.000000        7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429    44952.254576
# std     97.249970  5.494020e+06  4.576187e+06  0.016592     6954.983875
# min     35.467000  1.785387e+06  2.424950e+05  0.873000    35733.025633
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500    40265.998421
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000    45729.239975
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000    49103.699626
# max    318.523000  1.734808e+07  9.984670e+06  0.916000    54464.120330
#
#        Population Per Surface Area
# count                     7.000000
# mean                      0.000167
# std                       0.000124
# min                       0.000004
# 25%                       0.000067
# 50%                       0.000201
# 75%                       0.000246
# ...

# %%
population = df['Population']

# %%
population.min(), population.max()
# Out:
# (35.467, 318.523)

# %%
population.sum()
# Out:
# 751.118

# %%
population.sum()/len(population)
# Out:
# 107.30257142857144

# %%
population.median()
# Out:
# 64.511

# %%
population.quantile(.25)
# Out:
# 62.308
